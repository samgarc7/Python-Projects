# %%
import pandas as pd 
import numpy as np 

base = '../data_science_salaries.csv'
df = pd.read_csv(base)
display(df)
# Out:
#                      job_title experience_level employment_type work_models  \
# 0                Data Engineer        Mid-level       Full-time      Remote
# 1                Data Engineer        Mid-level       Full-time      Remote
# 2               Data Scientist     Senior-level       Full-time      Remote
# 3               Data Scientist     Senior-level       Full-time      Remote
# 4                 BI Developer        Mid-level       Full-time     On-site
# ...                        ...              ...             ...         ...
# 6594        Staff Data Analyst      Entry-level        Contract      Hybrid
# 6595        Staff Data Analyst  Executive-level       Full-time     On-site
# 6596  Machine Learning Manager     Senior-level       Full-time      Hybrid
# 6597             Data Engineer        Mid-level       Full-time      Hybrid
# 6598            Data Scientist     Senior-level       Full-time     On-site
#
# ...

# %%
df[df['salary'] > 7000000]
# Out:
#                            job_title experience_level employment_type  \
# 6092  Lead Machine Learning Engineer     Senior-level       Full-time
# 6353                 BI Data Analyst        Mid-level       Full-time
# 6428                     ML Engineer        Mid-level       Full-time
# 6504                  Data Scientist        Mid-level       Full-time
# 6570                  Data Scientist        Mid-level       Full-time
#
#      work_models  work_year employee_residence    salary salary_currency  \
# 6092      Hybrid       2022              India   7500000             INR
# 6353      Hybrid       2021            Hungary  11000000             HUF
# 6428      Hybrid       2021              Japan   8500000             JPY
# 6504      Remote       2021              Chile  30400000             CLP
# 6570      Hybrid       2020            Hungary  11000000             HUF
#
#       salary_in_usd company_location company_size
# 6092          95386            India        Large
# ...

# %%
#ordenando tabela por coluna e por ordem de index recriada
df = df.sort_values(by=salaries, ascending=False).reset_index(drop = True)
df

# %%
#query in tabel
df.query('(experience_level == "Senior-level")& (work_models == "Remote") & (salary > 1000000)')

# %%
#media por criterio 
mean_salary = df.groupby('experience_level')['salary'].mean()
mean_salary

# %%
salarios= df[salaries]
salarios_mediana = np.mean(salarios)
print(f'{salarios_mediana:.2f}')
# Out:
# 179283.26

# %%
media_mediana = df['salary'].agg([np.mean, np.median]).T
media_mediana

# %%
import plotly.io as pio
pio.renderers.default = 'notebook_connected'

# %%
import plotly.express as px

# %%
grafico = px.histogram(df, x="experience_level")
grafico.show()
# Out:
# <div>                            <div id="d4c78375-a27f-4c15-915c-a8350d20fd77" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d4c78375-a27f-4c15-915c-a8350d20fd77")) {                    Plotly.newPlot(                        "d4c78375-a27f-4c15-915c-a8350d20fd77",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"experience_level=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["Mid-level","Mid-level","Senior-level","Senior-level","Mid-level","Mid-level","Entry-level","Entry-level","Executive-level","Executive-level","Mid-level","Mid-level","Mid-level","Mid-le
# ...
